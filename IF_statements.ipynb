# %%
# Variables / arvot

# number1 = 7
# number2 = 7

number1 = 15
number2 = 30
number3 = 45

name1 = "Alice"
name2 = "Bob"
name3 = "Alice"

# If statements / jos sitaatiot

if number1 == number2:
    print("number1 and number2 are equal")

if number1 > number2:
    print("number1 is greater than number2")

if number1 != number2:
    print("number1 and number2 are NOT equal")



if number1 == number2 == number3:
    print("All numbers are equal")

if number1 == number2 or number2 == number3:
    print("Either number1 and number2 are equal OR number2 and number3 are equal")

if number1 > number2 and number1 > number3:
    print("number1 is greater than both number2 and number3")

if number1 > number2:
    print("number1 is greater than number2")
else:
    if number2 > number3:
        print("number2 is greater than number3")

if number1 > number2:
    print("number1 is greater than number2")
else:
    if number2 > number3:
        print("number2 is greater than number3")



if name1 == name2:
    print("name1 and name2 are equals")

if name1 != name2:
    print("name1 and name2 are NOT equals")

if name1 == name2:
    print("name1 and name2 are equals")
else:
    if name1 == name3:
        print("name1 and name3 are equals")
# Out:
# number1 and number2 are NOT equal
# name1 and name2 are NOT equals
# name1 and name3 are equals
