# %%
# Variables / Arvot

creator = "Niko Saartenkorpi"

number1 = 4

number2 = 2

# calculations / laskut

multiplication = number1 * number2

addition = number1 + number2

division = number1 / number2

subtraction = number1 - number2

# tulostin appi / printer app + made by:

print("Printer app")

print("This app is made by:", creator)

# number prints / numero printit

print ("Value of the number1 = ", number1)

print ("Value of the number2 = ", number2)

print (number1, "*", number2, "= ", multiplication)

print (number1, "+", number2, "= ", addition)

print (number1, "/", number2, "= ", division )

print (number1, "-", number2, "= ", subtraction)
