# %%
    # version 1.0.0 ( beta )

#right_name = "mauri"
#guess = input("guess my name: ")

#if guess == right_name:
#    print("congratulation!")
#else:
#    print("wrong guess!")


    #   version 1.1.0 ( with loop )


# right_name = "jorma"

# while True:
#     guess = input("guess my name (lower case letters): ")
#     if guess == right_name:
#         print("congratulation!")
#         break
#     else:
#         print("wrong one, try again!")


    # version 1.2.0 ( complete )


right_name = "jasser"
attempts = 0

while True:
    guess = input("guess my name (lower case letters): ")
    attempts += 1
    
    if guess == right_name:
        print(f"congratulation! you guessed it after {attempts} attempts.")
        break
    else:
        print("Wrong guess.")
        quit_choice = input("Do you want to quit? (Y/N): ").lower()
        if quit_choice == "y":
            print(f"program quit. you had {attempts} attempts. correct name was = {right_name}.")
            break
        else:
            print("try again!")
# Out:
# Wrong guess.
# you quit. You had 1 attempts. correct name was = jasser.
